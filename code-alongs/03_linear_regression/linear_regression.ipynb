# %% [markdown]
# # Linear Regression Code Along
#
#     - We have labels -> supervised learning
#     - Try to predict real number -> regression
#     - Predict discrete values -> classification

# %%
import pandas as pd

df = pd.read_csv("../../data/Advertising.csv", index_col=0)
df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
df.shape
# Out:
# (200, 4)

# %%
print(f"{df.shape[0]} samples")
print(f"{df.shape[1]-1} features")
print("sales column is our label/target")
# Out:
# 200 samples
# 3 features
# sales column is our label/target

# %% [markdown]
# ## EDA left for the reader (me)

# %% [markdown]
# ## divide data into X and Y

# %%
# Tuple unpacking
# X will contain all columns except 'sales' / Design matrix /features / independent variables
# y will contain the 'sales' column / Target variable / label / dependent variable

X, y = df.drop("sales", axis=1), df["sales"]
X.head()
# Out:
#       TV  radio  newspaper
# 1  230.1   37.8       69.2
# 2   44.5   39.3       45.1
# 3   17.2   45.9       69.3
# 4  151.5   41.3       58.5
# 5  180.8   10.8       58.4

# %%
y.head()
type(y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Scikit-learn Steps
#
# 1. Train | test split  or  train | val | test split
# 2. Scale dataset
#     - Many algorithms require scaling, some don't
#     - Different types of scaling (ex. feature standardization, min-max scaling)
#     - Scale training data and test data to the training dats parameters, to avoid data leakage
# 3. Fit algorithm to training data
# 4. Predict on test data
# 5. Evaluation metrics

# %% [markdown]
# ## 1. Train|Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

print(f"{X_train.shape = }")
print(f"{y_train.shape = }")
print(f"{X_test.shape = }")
print(f"{y_test.shape = }")
# Out:
# X_train.shape = (134, 3)
# y_train.shape = (134,)
# X_test.shape = (66, 3)
# y_test.shape = (66,)

# %%
X_train.head()
# Out:
#         TV  radio  newspaper
# 43   293.6   27.7        1.8
# 190   18.7   12.1       23.4
# 91   134.3    4.9        9.3
# 137   25.6   39.0        9.3
# 52   100.4    9.6        3.6

# %%
y_train.head()
# Out:
# 43     20.7
# 190     6.7
# 91     11.2
# 137     9.5
# 52     10.7
# Name: sales, dtype: float64

# %% [markdown]
# ## 2. Feature scaling
#     - Min - Max scaling
#     - Values transformed into 0 to 1

# %%
from sklearn.preprocessing import MinMaxScaler

# Instantiate an instance of the MinMaxScaler Class
# This will scale the data to a range between 0 and 1
scaler = MinMaxScaler()
type(scaler)
# Out:
# sklearn.preprocessing._data.MinMaxScaler

# %%
scaler.fit(X_train)
scaled_X_train = scaler.transform(X_train)
scaled_X_test = scaler.transform(X_test)

print(f"{scaled_X_train.min() = }")
print(f"{scaled_X_train.max() = }")
print(f"{scaled_X_test.min() = }")
print(f"{scaled_X_test.max() = }")
# Out:
# scaled_X_train.min() = np.float64(0.0)
# scaled_X_train.max() = np.float64(1.0)
# scaled_X_test.min() = np.float64(0.005964214711729622)
# scaled_X_test.max() = np.float64(1.1302186878727631)

# %%
scaled_X_train.shape
# Out:
# (134, 3)

# %%
scaled_X_train[:5]  # Display the first 5 rows of the scaled training data
# Out:
# array([[0.99053094, 0.55846774, 0.01491054],
#        [0.06087251, 0.24395161, 0.22962227],
#        [0.45180927, 0.09879032, 0.08946322],
#        [0.08420697, 0.78629032, 0.08946322],
#        [0.33716605, 0.19354839, 0.03280318]])

# %%
type(scaled_X_train)
# Out:
# numpy.ndarray

# %% [markdown]
# ## 3. Linear Regression
#
# $y = w_0 + w_1x_1 + w_2x_2 + w_3x_3$

# %%
from sklearn.linear_model import LinearRegression
    # Instantiate an instance of the LinearRegression class
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(scaled_X_train, y_train)
print(f"Parameters or weights: {model.coef_}")
print(f"Intercept: {model.intercept_}")
# Out:
# Parameters or weights: [13.20747617  9.75285112  0.61108329]
# Intercept: 2.7911595196243653

# %% [markdown]
# ## 4. Prediction

# %%
sample_features = scaled_X_test[0].reshape(1, -1)  # Reshape to 2D array for prediction
sample_features
# Out:
# array([[0.54988164],
#        [0.63709677],
#        [0.52286282]])

# %%
model.predict([sample_features])  # Predicting the sales for the first sample in the test set
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 model.predict([sample_features])  # Predicting the sales for the first sample in the test set
#
# File c:\Users\user\Desktop\Skola\Ai_engineering_Max_Gustafsson\.venv\Lib\site-packages\sklearn\linear_model\_base.py:298, in LinearModel.predict(self, X)
#     284 def predict(self, X):
#     285     """
#     286     Predict using the linear model.
#     287
#    (...)    296         Returns predicted values.
#     297     """
# --> 298     return self._decision_function(X)
#
# File c:\Users\user\Desktop\Skola\Ai_engineering_Max_Gustafsson\.venv\Lib\site-packages\sklearn\linear_model\_base.py:277, in LinearModel._decision_function(self, X)
#     274 def _decision_function(self, X):
#     275     check_is_fitted(self)
# --> 277     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     278     coef_ = self.coef_
#     279     if coef_.ndim == 1:
#
# File c:\Users\user\Desktop\Skola\Ai_engineering_Max_Gustafsson\.venv\Lib\site-packages\sklearn\utils\validation.py:2954, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2952         out = X, y
#    2953 elif not no_val_X and no_val_y:
# -> 2954     out = check_array(X, input_name="X", **check_params)
#    2955 elif no_val_X and not no_val_y:
#    2956     out = _check_y(y, **check_params)
#
# File c:\Users\user\Desktop\Skola\Ai_engineering_Max_Gustafsson\.venv\Lib\site-packages\sklearn\utils\validation.py:1099, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1094     raise ValueError(
#    1095         "dtype='numeric' is not compatible with arrays of bytes/strings."
#    1096         "Convert your data to numeric values explicitly instead."
#    1097     )
#    1098 if not allow_nd and array.ndim >= 3:
# -> 1099     raise ValueError(
#    1100         f"Found array with dim {array.ndim},"
#    1101         f" while dim <= 2 is required{context}."
#    1102     )
#    1104 if ensure_all_finite:
#    1105     _assert_all_finite(
#    1106         array,
#    1107         input_name=input_name,
#    1108         estimator_name=estimator_name,
#    1109         allow_nan=ensure_all_finite == "allow-nan",
#    1110     )
#
# ValueError: Found array with dim 3, while dim <= 2 is required by LinearRegression.
