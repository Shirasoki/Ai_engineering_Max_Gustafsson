# %% [markdown]
# ## For this project im going to clean auction house data for my favorite game, this is the start with EDA

# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
df = pd.read_csv("../data/auctions.csv")

# %%
df.head()
# Out:
#    scan-time itemid  modifier      player  duration  quantity  minbid  buyout
# 0   1.205271   8182       NaN   Elderling         4         1     190   200.0
# 1   1.205271   8182       NaN        Proc         3         1     100     NaN
# 2   1.205271   4562     585.0  Thunderaan         3         1     500   900.0
# 3   1.205271   2976       NaN     Lerwick         3         1    1056  2000.0
# 4   1.205271   3654       NaN    Slowpoke         3         1    1000  1500.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313920 entries, 0 to 313919
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   scan-time  313920 non-null  float64
#  1   itemid     313920 non-null  object
#  2   modifier   46406 non-null   float64
#  3   player     128560 non-null  object
#  4   duration   313920 non-null  int64
#  5   quantity   313920 non-null  int64
#  6   minbid     313920 non-null  int64
#  7   buyout     301546 non-null  float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 19.2+ MB

# %%
df.shape
# Out:
# (313920, 8)

# %%
df_clean = df["buyout"].notna() & (df["quantity"] >= 1) & (df["buyout"] > 0)

# %%
df_clean.head()
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# dtype: bool
